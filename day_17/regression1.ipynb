# %% [markdown]
# # 📘 Notes: Regression in Machine Learning
# ## 🔹 What is Regression?
# Regression ek aisi supervised machine learning technique hai jo kisi cheez ki value predict karti hai — numbers (continuous output) mein.
#
# Example:
#
# Ghar ki price kitni hogi?
#
# Bill ke hisaab se tip kitni deni chahiye?
#
# Student ki study hours ke mutabiq marks kya aayenge?
#
# 📌 Jab model se hum "kitna?" ya "kya number?" ka sawal karein → to regression use hota hai.
#
# 🔹 Why Use Regression?
# Future prediction
#
# Business decision making
#
# Financial forecasting
#
# Data trend analysis
#
# 🧠 Types of Regression
# 1. Linear Regression 📈
# Sirf ek feature (input) hota hai
#
# Input aur output ka relation straight line hota hai
#
# Formula: y = mx + c
#
# ✅ Example:
# total_bill barhta hai → tip bhi barhti hai.
#
# 2. Multiple Linear Regression
# 1 se zyada features hotay hain
#
# Still straight line hoti hai but in multi-dimensional space
#
# ✅ Example:
# House price based on size, location, rooms
#
# 3. Polynomial Regression 🔁
# Jab relation straight nahi hota → curve banata hai
#
# Model higher degree polynomial banata hai:
# y = a + bx + cx² + dx³ + ...
#
# ✅ Example:
# Age vs Experience → pehle performance barhti hai, phir ghat jaati hai
#
# 4. Ridge Regression (L2 Regularization)
# Linear regression + penalty lagata hai (overfitting se bachata hai)
#
# Extra large coefficients ko control karta hai
#
# 5. Lasso Regression (L1 Regularization)
# Similar to Ridge, but yeh some features ko zero bhi kar deta hai
#
# Useful for feature selection
#
# 6. Logistic Regression ⚠️
# Naam regression ka hai, lekin yeh classification task hoti hai.
#
# Output is not number, but Yes/No, 0/1, True/False
#
# Used for: spam detection, disease prediction, etc.
#
# 📝 Summary Table
# Type	Use Case	Output Type
# Linear Regression	1 feature, straight line relation	Number
# Multiple Linear	Many features	Number
# Polynomial Regression	Curved data	Number
# Ridge / Lasso Regression	Prevent overfitting	Number
# Logistic Regression	Classification (Yes/No)	0 or 1
#
# Let me know if you want this in PDF format or with diagrams or code examples too! 🌼
# Or agar chaho tu yeh notes mein tumhare naam se export kr dungi 💫

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt  

from sklearn.preprocessing import StandardScaler  
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# load the data tips form sns
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# split the data into x and y 
x=df[['total_bill']]
scalar= StandardScaler()
x=scalar.fit_transform(x)
y=df['tip']

# %%
# split the data into train test split 
x_train, x_test , y_train , y_test= train_test_split(x,y , test_size=0.2)

# %%
# call the model 
model= LinearRegression()

# %%
# train the model 
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# take a model intercept and slope, make an equation
print(model.intercept_)
print(model.coef_)
print('y=', model.intercept_,'+', model.coef_,'* x')
# Out:
# 2.9947963400968525
# [0.93724792]
# y= 2.9947963400968525 + [0.93724792] * x

# %%
# predict 
y_pred= model.predict(x_test)

# %%
x_test
# Out:
# array([[-1.13752491],
#        [-0.42839691],
#        [-1.23995452],
#        [ 0.94145831],
#        [ 0.3336343 ],
#        [-1.28722972],
#        [-1.37615212],
#        [-0.38112171],
#        [-0.42839691],
#        [ 1.20147191],
#        [-0.49143051],
#        [-1.06886331],
#        [-0.79084011],
#        [ 3.49206794],
#        [ 0.76586471],
#        [-0.98669451],
#        [-0.49818411],
#        [-1.09362651],
#        [-0.79871931],
#        [ 1.34217191],
#        [-0.3057065 ],
#        [-0.1683833 ],
#        [-0.71655051],
#        [ 0.1017607 ],
#        [ 2.40924072],
#        [-0.53758011],
#        [ 1.45135511],
#        [ 2.75930233],
#        [-0.55784091],
#        [-1.12626891],
#        [-0.53195211],
#        [-0.72217851],
#        [-0.76382571],
#        [ 0.2154463 ],
#        [ 2.05805352],
#        [-0.73230891],
#        [-0.2471753 ],
#        [-0.2786921 ],
#        [-1.26809452],
#        [-0.2809433 ],
#        [-0.2212865 ],
# ...

# %%
y_pred= model.predict(x_test)

# %%
# evluate the model 
print('MSE=',mean_squared_error(y_test, y_pred))
print('R2=',r2_score(y_test, y_pred))
print('RMSR=', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE= 1.139441838825201
# R2= 0.46820370893248553
# RMSR= 1.0674464102825962

# %%
# plot the model and data
plt.scatter (x_test, y_test)
plt.plot(x_test,y_pred,color= 'red')
plt.show()
