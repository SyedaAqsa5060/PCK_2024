# %% [markdown]
# # Data Wrangling  beginner to pro

# %% [markdown]
# # Data wrangling
# data wrangling is the process of `cleaning`, `transforming`, and `organizing` data so it is used
# for data `analysis` and `visulization`. it is important step for data analysis because `raw data` is
# `incomplete`, `inconsistance` and `unstructured formate` , which make difficult to deal with data
# data wrangling can provide to deal with data with consistancy , accurate and useful for decision making

# %% [markdown]
# ## steps
# 1- gathering the data
# 2-tool to clean the data

# %%
# import libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# 3- assessing the data

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.drop(columns='deck',inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['age'] = df['age'].fillna(df['age'].mean())  # Now fill NaNs
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0]) 
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df['embark_town']=df['embark_town'].fillna(df['embark_town'].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # outliears removal

# %% [markdown]
# # with the help of visulization

# %%
import seaborn  as sns 
sns.boxenplot(df, x='sex', y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# IQR methods 
Q1= df['age'].quantile(0.25)
Q3= df['age'].quantile(0.75)
IQR= Q3-Q1
IQR
# Out:
# np.float64(13.0)

# %%
# removing outliears 
lower_bound= Q1-1.5 * IQR
upper_bound= Q3+ 1.5 *IQR
df= df[(df['age']>lower_bound)&(df['age']<upper_bound)]

# %%
df.shape
# Out:
# (825, 14)

# %%
Q1= df['fare'].quantile(0.25)
Q3= df['fare'].quantile(0.75)
IQR= Q3-Q1
IQR
# removing outliears 
lower_bound= Q1-1.5 * IQR
upper_bound= Q3+ 1.5 *IQR
df= df[(df['fare']>lower_bound)&(df['fare']<upper_bound)]

# %%
df.shape
# Out:
# (718, 14)

# %%
# # zscorer  method for the removal of outliears 
# # pip install scipy 
# from scipy import stats
# import numpy as np 

# zscore= np.abs(stats.zscore(df['age']))
# threshold= 3
# df= df[(z<threshold).all(axis=1)]

# %% [markdown]
# # finding and droping duplicates

# %%
df.shape
# Out:
# (718, 14)

# %%
df1=df.duplicated()

# %%
df1.shape
# Out:
# (718,)

# %%
df1.head()
# Out:
# 0    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df_duplicates= df[df.duplicated]

# %%
df_duplicates.head()
# Out:
#     survived  pclass     sex        age  sibsp  parch    fare embarked  class  \
# 47         1       3  female  29.699118      0      0  7.7500        Q  Third
# 76         0       3    male  29.699118      0      0  7.8958        S  Third
# 77         0       3    male  29.699118      0      0  8.0500        S  Third
# 87         0       3    male  29.699118      0      0  8.0500        S  Third
# 95         0       3    male  29.699118      0      0  8.0500        S  Third
#
#       who  adult_male  embark_town alive  alone
# 47  woman       False   Queenstown   yes   True
# 76    man        True  Southampton    no   True
# 77    man        True  Southampton    no   True
# 87    man        True  Southampton    no   True
# 95    man        True  Southampton    no   True

# %%
# finding _duplicates
df.duplicated().sum()
# Out:
# np.int64(103)

# %%
#droping _ duplicates 
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (615, 14)

# %% [markdown]
# # Normalization of data
# ## to bring data at one scale

# %%
# 1.import libraries 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
#2.  data 
df
# 3.select the column to normalize 
col_to_normalize= ['age', 'fare']
# 4. create the scalar function /tool
scaler = MinMaxScaler()
# 5 fit the data and transformer the data to normalize 
df[col_to_normalize]= scaler.fit_transform(df[col_to_normalize])
# 6. check the data
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.372549      1      0  0.118118        S
# 2           1       3  female  0.450980      0      0  0.129115        S
# 3           1       1  female  0.627451      1      0  0.865114        S
# 4           0       3    male  0.627451      0      0  0.131152        S
# 5           0       3    male  0.523512      0      0  0.137804        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.705882      0      5  0.474509        Q
# 887         1       1  female  0.313725      0      0  0.488765        S
# 888         0       3  female  0.523512      1      2  0.382051        S
# 889         1       1    male  0.450980      0      0  0.488765        C
# 890         0       3    male  0.568627      0      0  0.126264        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  615.000000  615.000000  615.000000  615.000000  615.000000  615.000000
# mean     0.360976    2.469919    0.497584    0.460163    0.365854    0.298831
# std      0.480674    0.741063    0.209485    0.894039    0.835572    0.221334
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.372549    0.000000    0.000000    0.128640
# 50%      0.000000    3.000000    0.523512    0.000000    0.000000    0.211798
# 75%      1.000000    3.000000    0.607843    1.000000    0.000000    0.423596
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %%
# 1.import libraries 
import pandas as pd
from sklearn.preprocessing import StandardScaler
#2.  data 
df
# 3.select the column to normalize 
col_to_normalize= ['age', 'fare']
# 4. create the scalar function /tool
scaler = StandardScaler()
# 5 fit the data and transformer the data to normalize 
df[col_to_normalize]= scaler.fit_transform(df[col_to_normalize])
# 6. check the data

# %%
df.describe()
# Out:
#          survived      pclass           age       sibsp       parch  \
# count  615.000000  615.000000  6.150000e+02  615.000000  615.000000
# mean     0.360976    2.469919  3.061688e-16    0.460163    0.365854
# std      0.480674    0.741063  1.000814e+00    0.894039    0.835572
# min      0.000000    1.000000 -2.377209e+00    0.000000    0.000000
# 25%      0.000000    2.000000 -5.973545e-01    0.000000    0.000000
# 50%      0.000000    3.000000  1.238725e-01    0.000000    0.000000
# 75%      1.000000    3.000000  5.267644e-01    1.000000    0.000000
# max      1.000000    3.000000  2.400296e+00    5.000000    6.000000
#
#                fare
# count  6.150000e+02
# mean  -1.213122e-16
# std    1.000814e+00
# min   -1.351236e+00
# 25%   -7.695610e-01
# 50%   -3.935399e-01
# 75%    5.641565e-01
# max    3.170505e+00

# %% [markdown]
#  ### x_stand= (x-mean(x))/std(x)
#
#  #### where :  x_stand is standarized variable x  is the original variable mean(x)is the mean of
#  #### variable x std(x) standard deviation of x

# %% [markdown]
# # log transformatin (normalize the data )

# %%
kashti= sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import numpy as np 
kashti['age']=kashti['age'].fillna(kashti['age'].median())
kashti['fare']=kashti['fare'].fillna(kashti['fare'].median())

# log _ transform 

kashti['age']= np.log(kashti['age'])
kashti['fare']=np.log(khasti['fare'])
kashti.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 8
#       5 # log _ transform
#       7 kashti['age']= np.log(kashti['age'])
# ----> 8 kashti['fare']=np.log(khasti['fare'])
#       9 kashti.head()
#
# NameError: name 'khasti' is not defined

# %%
sns.boxenplot(data=kashti, x='sex', y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.histplot(kashti['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # Oraganizing the data

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# creating the column 
df['family_size']= df['sibsp'] + df['parch']

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male -0.597354      1      0 -0.817136        S
# 2           1       3  female -0.222648      0      0 -0.767410        S
# 3           1       1  female  0.620441      1      0  2.560585        S
# 4           0       3    male  0.620441      0      0 -0.758201        S
# 5           0       3    male  0.123872      0      0 -0.728122        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.995147      0      5  0.794372        Q
# 887         1       1  female -0.878384      0      0  0.858832        S
# 888         0       3  female  0.123872      1      2  0.376301        S
# 889         1       1    male -0.222648      0      0  0.858832        C
# 890         0       3    male  0.339411      0      0 -0.780302        Q
#
#      class    who  adult_male  embark_town alive  alone  family_size
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.swarmplot(data=df, x='sex' , y= 'age',hue='family_size')
# Out:
# c:\Users\aqso\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='age'>
# c:\Users\aqso\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\aqso\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# rename the columns 
df= df.rename(columns={'survived': 'survival'})  # using the dictonary 
df
# Out:
#      survival  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male -0.597354      1      0 -0.817136        S
# 2           1       3  female -0.222648      0      0 -0.767410        S
# 3           1       1  female  0.620441      1      0  2.560585        S
# 4           0       3    male  0.620441      0      0 -0.758201        S
# 5           0       3    male  0.123872      0      0 -0.728122        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.995147      0      5  0.794372        Q
# 887         1       1  female -0.878384      0      0  0.858832        S
# 888         0       3  female  0.123872      1      2  0.376301        S
# 889         1       1    male -0.222648      0      0  0.858832        C
# 890         0       3    male  0.339411      0      0 -0.780302        Q
#
#      class    who  adult_male  embark_town alive  alone  family_size
# ...

# %%
table= pd.pivot_table(df, values='fare', index='pclass',
                      columns='survival',aggfunc=np.sum)
table
# Out:
# C:\Users\aqso\AppData\Local\Temp\ipykernel_14036\1011084455.py:1: FutureWarning: The provided callable <function sum at 0x0000028BFFE05D00> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table= pd.pivot_table(df, values='fare', index='pclass',
# survival           0          1
# pclass
# 1          47.098956  86.811732
# 2          -1.053066  13.921025
# 3        -109.690971 -37.087677

# %%
sns.scatterplot(data=df, x='fare', y='age', hue='who')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
df.head()
# Out:
#    survival  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male -0.597354      1      0 -0.817136        S  Third
# 2         1       3  female -0.222648      0      0 -0.767410        S  Third
# 3         1       1  female  0.620441      1      0  2.560585        S  First
# 4         0       3    male  0.620441      0      0 -0.758201        S  Third
# 5         0       3    male  0.123872      0      0 -0.728122        Q  Third
#
#      who  adult_male  embark_town alive  alone  family_size
# 0    man        True  Southampton    no  False            1
# 2  woman       False  Southampton   yes   True            0
# 3  woman       False  Southampton   yes  False            1
# 4    man        True  Southampton    no   True            0
# 5    man        True   Queenstown    no   True            0

# %% [markdown]
# # saving the organized data in to csv file

# %%
# after processing the data 
df.to_csv("preprocessing_data.csv")

# %%
# after processing the data 
df.to_excel("preprocessing_data.xlsx")

# %%
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
# line plot 
sns.lineplot(data=df, x='family_size',y='age')
# Out:
# <Axes: xlabel='family_size', ylabel='age'>
